# %%
import pandas as pd

# %%
df  = pd.read_csv("../data/mplads_completed_works_2026-08-22.csv")

# %%
df.head(10)
# Out:
#    Work ID                                   Work Description       Category  \
# 0   134703  Upgradation of Road from Madhavaram Village to...  Normal/Others
# 1   135593  Construction of CC Road from Amudala Village t...  Normal/Others
# 2   135595  Construction of CC road from Amudala Village t...  Normal/Others
# 3   135639  Construction of Under Ground Drainage at Thala...  Normal/Others
# 4   135640  Construction of Under Ground Draiange at Thala...  Normal/Others
# 5   135641  Construction of Under Ground Drainage at Thala...  Normal/Others
# 6   135642  Construction of Under Ground Drainage at Penum...  Normal/Others
# 7   135643  Construction of Under Ground Drainage at Penum...  Normal/Others
# 8   135645  Construction of CC Road in Payanagaripalli HW ...  Normal/Others
# 9   135646  Construction of CC Road at Hand Borewell to Sr...  Normal/Others
#
#                   MP Name Constituency           State      House  \
# ...

# %%
df.columns
# Out:
# Index(['Work ID', 'Work Description', 'Category', 'MP Name', 'Constituency',
#        'State', 'House', 'Final Amount (₹)', 'Completed Date', 'Has Images',
#        'Average Rating', 'IDA'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43173 entries, 0 to 43172
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Work ID           43173 non-null  int64
#  1   Work Description  43088 non-null  object
#  2   Category          43168 non-null  object
#  3   MP Name           43173 non-null  object
#  4   Constituency      43173 non-null  object
#  5   State             43173 non-null  object
#  6   House             43173 non-null  object
#  7   Final Amount (₹)  43173 non-null  float64
#  8   Completed Date    43173 non-null  object
#  9   Has Images        43173 non-null  bool
#  10  Average Rating    4 non-null      float64
#  11  IDA               43173 non-null  object
# dtypes: bool(1), float64(2), int64(1), object(8)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#              Work ID  Final Amount (₹)  Average Rating
# count   43173.000000      4.317300e+04             4.0
# mean   176111.147384      5.475696e+05             2.0
# std     49892.650168      1.024150e+06             2.0
# min      1211.000000      8.448000e+03             1.0
# 25%    150791.000000      1.765280e+05             1.0
# 50%    178174.000000      3.000000e+05             1.0
# 75%    209142.000000      6.000000e+05             2.0
# max    292762.000000      4.647040e+07             5.0

# %%
print(df['Average Rating'].iloc[0])
df['Average Rating'].isnull().count()
# Out:
# nan
# 43173
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df.shape
# Out:
# (43173, 12)
