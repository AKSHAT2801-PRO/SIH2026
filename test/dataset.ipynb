# %%
import pandas as pd

# %%
df  = pd.read_csv("../data/mplads_expenditures_2026-08-22.csv")

# %%
df.head(20)
# Out:
#                     MP Name    Constituency          State      House  \
# 0              ADITYA YADAV          BADAUN  Uttar Pradesh  Lok Sabha
# 1              ADITYA YADAV          BADAUN  Uttar Pradesh  Lok Sabha
# 2   SUKANTA KUMAR PANIGRAHI       KANDHAMAL         Odisha  Lok Sabha
# 3              ANANTA NAYAK        KEONJHAR         Odisha  Lok Sabha
# 4   SUKANTA KUMAR PANIGRAHI       KANDHAMAL         Odisha  Lok Sabha
# 5              Vijay Baghel            DURG   Chhattisgarh  Lok Sabha
# 6                SUNIL BOSE  CHAMARAJANAGAR      Karnataka  Lok Sabha
# 7              Vijay Baghel            DURG   Chhattisgarh  Lok Sabha
# 8         Ajay Kumar Mandal       BHAGALPUR          Bihar  Lok Sabha
# 9             ZIA UR REHMAN         SAMBHAL  Uttar Pradesh  Lok Sabha
# 10            ZIA UR REHMAN         SAMBHAL  Uttar Pradesh  Lok Sabha
# 11      BABU SINGH KUSHWAHA         JAUNPUR  Uttar Pradesh  Lok Sabha
# ...

# %%
df.tail(2)
# Out:
#                              MP Name         Constituency      State  \
# 106261  Shri Jairam Ramesh (2022-28)  Sitting Rajya Sabha  Karnataka
# 106262  Shri Jairam Ramesh (2022-28)  Sitting Rajya Sabha  Karnataka
#
#               House                                   Work Description  \
# 106261  Rajya Sabha  Construction of roads, link roads, pathways or...
# 106262  Rajya Sabha  Construction of roads, link roads, pathways or...
#
#                              Vendor  \
# 106261  KRIDL BHUSIRI ACCOUNT WORKS
# 106262  KRIDL BHUSIRI ACCOUNT WORKS
#
#                                                     IDA  \
# 106261  CHIKKAMAGALURU(DEPUTY COMMISSIONER CHIKMAGALUR)
# 106262  CHIKKAMAGALURU(DEPUTY COMMISSIONER CHIKMAGALUR)
#
#         Expenditure Amount (₹)          Expenditure Date   Payment Status
# 106261                800000.0  2024-10-15T00:00:00.000Z  Payment Success
# 106262                600000.0  2026-01-31T00:00:00.000Z  Payment Success

# %%
df.columns
# Out:
# Index(['MP Name', 'Constituency', 'State', 'House', 'Work Description',
#        'Vendor', 'IDA', 'Expenditure Amount (₹)', 'Expenditure Date',
#        'Payment Status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106263 entries, 0 to 106262
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   MP Name                 106263 non-null  object
#  1   Constituency            106263 non-null  object
#  2   State                   106263 non-null  object
#  3   House                   106263 non-null  object
#  4   Work Description        106263 non-null  object
#  5   Vendor                  106263 non-null  object
#  6   IDA                     106263 non-null  object
#  7   Expenditure Amount (₹)  106263 non-null  float64
#  8   Expenditure Date        106263 non-null  object
#  9   Payment Status          106263 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 8.1+ MB

# %%
df.describe()
# Out:
#        Expenditure Amount (₹)
# count            1.062630e+05
# mean             3.687770e+05
# std              6.527099e+05
# min              1.000000e-02
# 25%              7.000000e+04
# 50%              1.999990e+05
# 75%              4.579810e+05
# max              3.256225e+07

# %%
len(df[df["Constituency"]== "JAUNPUR"])
# Out:
# 650

# %%
len(df[
    (df["Constituency"] == "JAUNPUR") &
    (df["Work Description"] == "Street lights")
])
# Out:
# 593

# %%
len(df[
    (df["Constituency"] == "JAUNPUR") &
    (df["Work Description"] == "Street lights") &
    (df["Payment Status"] == "Payment Success" )
])
# Out:
# 448

# %%
print (448 * 19992)
# Out:
# 8956416

# %% [markdown]
# ### Paid Amount: Eighty Nine Lakh fifty six thousand four hundred sixteen

# %%
print (593 * 19992)
# Out:
# 11855256

# %% [markdown]
# ### After Payment Processing: One Crore Eighteen Lakhs fifty five thousand two hundred fifty six

# %%
print (11855256 - 8956416)
# Out:
# 2898840

# %% [markdown]
# ### Due Amount: Twenty Eight Lakhs Ninty Eight thousand eight hundred forty
